# %% [markdown]
# <div style="border-radius:10px;
#             border : #015a2c solid;
#             background-color:#D7D9DB;
#            font-size:110%;
#            letter-spacing:0.5px;
#             text-align: center">
# ​
# <center><h1 style="padding: 25px 0px; color:#015a4c; font-weight: bold; font-family: Cursive">
# Amit Project for Data Science Module <br><br>💡💡💡💡💡 <br><br> DEPI_BS_DS_R3  </h1></center>
# <center><h3 style="padding-bottom: 25px; color:#025b2c; font-weight: bold; font-style:italic; font-family: Cursive">
# Using Project: Trip data Ford go bike  </h3></center>
# ​
# </div>

# %% [markdown]
# # Part I - (Dataset Exploration for Ford GoBike)
#
# ### worked by (MOSTAFA MAHMOUD OSMAN SDEAK/2026 )
#
# ## Introduction
#
# .
#
# > **Let's introduce our dataset:**
#
#
# ======================================
#
# .
#
# **This data set information was produced from `Ford GoBike` System** the information in it talked about individual rides that were made in a bike-sharing system for covering San Francisco Bay area.**
#
# .

# %% [markdown]
# > ## And here are the main exploring questions
#
#
#
#    **==================================================**
#
#
#
# - What is the structure of your dataset?
#
#
# - What are the main interesting features in the dataset?
#
#
# - What features in the dataset supported my investigation for these interesting features?
#
#
#
#
# .
#
# > ### Also here are the investigative questions classified into three types
#
#
#
#    **================================================**
#
#
#
#
# ###  <a href='#011'> Univariate Exploration</a>
#
# - <a href='#1'> 1 ) . What is the distribution of `User type`?</a>
# - <a href='#2'> 2 ) . What is the distribution for the `bike share users on all Trips`?</a>
# - <a href='#3'> 3 ) . What is the distribution for users' `ages`?</a>
# - <a href='#4'> 4 ) . Do the users' ages have `outlier` values?</a>
# - <a href='#5'> 5 ) . What is the distribution for the trip duration in `minutes`? </a>
# - <a href='#6'> 6) . What is the distribution for `member_gender`? </a>
# - <a href='#7'> 7) . What is the distribution for the trip duration in `Hours`?  </a>
#
#
#
#
# ##  <a href='#111'> Bivariate Exploration</a>
#
#
# - <a href='#8'> 8 ) . What the `average duration` of trip for the categories of `user type`? </a>
# - <a href='#9'> 9 ) . How long is the duration of the trip for `each gender` in `minutes`? </a>
# - <a href='#10'> 10 ) . How long is the duration of the trip for each `user_type` in `minutes`?  </a>
# - <a href='#11'> 11 ) . How the user distribution depending on their `Age` and `user_type` ?</a>
# - <a href='#12'>12 ). How the user distribution depending on their `Age` and `member_gender` ?  </a>
#
#
# ##  <a href='#1111'> Multivariate Exploration</a>
#
#
# - <a href='#13'> 13 ) . What is the Correlation between `each` variable in the dataset?</a>
# - <a href='#14'> 14 ) . What is the Correlation between `specific numeric variables` in the dataset?</a>
# - <a href='#15'> 15 ) . What is the  Correlation between `data_stat` variables in the dataset?</a>
#
#
# ##  <a href='#1100'> Conclusions </a>

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Import Libraries</p>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt

import seaborn as sb

# %matplotlib inline

# %%
df=pd.read_csv(r'C:\\Users\\MOSTAFA\Downloads\\fordgobike-tripdataFor201902.csv')

df
# Out:
#         duration_sec start_time end_time  start_station_id  \
# 0              52185    32:10.1  01:56.0              21.0
# 1              42521    53:21.8  42:03.1              23.0
# 2              61854    13:13.2  24:08.1              86.0
# 3              36490    54:26.0  02:36.8             375.0
# 4               1585    54:18.5  20:44.1               7.0
# ...              ...        ...      ...               ...
# 183411           271    00:20.6  04:52.1              24.0
# 183412           313    05:34.7  10:48.5              21.0
# 183413           141    06:05.5  08:27.2             278.0
# 183414           139    05:34.4  07:54.3             220.0
# 183415           271    00:20.6  04:52.1              24.0
#
#                                       start_station_name  \
# 0       Montgomery St BART Station (Market St at 2nd St)
# 1                          The Embarcadero at Steuart St
# 2                                Market St at Dolores St
# 3                                Grove St at Masonic Ave
# 4                                    Frank H Ogawa Plaza
# ...                                                  ...
# 183411                             Spear St at Folsom St
# 183412  Montgomery St BART Station (Market St at 2nd St)
# 183413                            The Alameda at Bush St
# 183414                       San Pablo Ave at MLK Jr Way
# 183415                             Spear St at Folsom St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.789625              -122.400811            13.0
# 1                    37.791464              -122.391034            81.0
# 2                    37.769305              -122.426826             3.0
# 3                    37.774836              -122.446546            70.0
# 4                    37.804562              -122.271738           222.0
# ...                        ...                      ...             ...
# 183411               37.789677              -122.390428            37.0
# 183412               37.789625              -122.400811            66.0
# 183413               37.331932              -121.904888           277.0
# 183414               37.811351              -122.273422           216.0
# 183415               37.789677              -122.390428            37.0
#
#                                     end_station_name  end_station_latitude  \
# 0                     Commercial St at Montgomery St             37.794231
# 1                                 Berry St at 4th St             37.775880
# 2       Powell St BART Station (Market St at 4th St)             37.786375
# 3                             Central Ave at Fell St             37.773311
# 4                              10th Ave at E 15th St             37.792714
# ...                                              ...                   ...
# 183411                           2nd St at Folsom St             37.785000
# 183412                         3rd St at Townsend St             37.778742
# 183413                     Morrison Ave at Julian St             37.333658
# 183414                      San Pablo Ave at 27th St             37.817827
# 183415                           2nd St at Folsom St             37.785000
#
#         end_station_longitude  bike_id   user_type  member_birth_year  \
# 0                 -122.402923     4902    Customer             1984.0
# 1                 -122.393170     2535    Customer                NaN
# 2                 -122.404904     5905    Customer             1972.0
# 3                 -122.444293     6638  Subscriber             1989.0
# 4                 -122.248780     4898  Subscriber             1974.0
# ...                       ...      ...         ...                ...
# 183411            -122.395936     1057  Subscriber             1989.0
# 183412            -122.392741     4960  Subscriber             1984.0
# 183413            -121.908586     3824  Subscriber             1990.0
# 183414            -122.275698     5095  Subscriber             1988.0
# 183415            -122.395936     1057  Subscriber             1989.0
#
#        member_gender bike_share_for_all_trip
# 0               Male                      No
# 1                NaN                      No
# 2               Male                      No
# 3              Other                      No
# 4               Male                     Yes
# ...              ...                     ...
# 183411          Male                      No
# 183412          Male                      No
# 183413          Male                     Yes
# 183414          Male                      No
# 183415          Male                      No
#
# [183416 rows x 16 columns]

# %%
df.shape
# Out:
# (183416, 16)

# %%
## check each var  datatype 
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 183416 entries, 0 to 183415
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183416 non-null  int64
#  1   start_time               183416 non-null  str
#  2   end_time                 183416 non-null  str
#  3   start_station_id         183219 non-null  float64
#  4   start_station_name       183219 non-null  str
#  5   start_station_latitude   183416 non-null  float64
#  6   start_station_longitude  183416 non-null  float64
#  7   end_station_id           183219 non-null  float64
#  8   end_station_name         183219 non-null  str
#  9   end_station_latitude     183416 non-null  float64
#  10  end_station_longitude    183416 non-null  float64
#  11  bike_id                  183416 non-null  int64
#  12  user_type                183416 non-null  str
#  13  member_birth_year        175151 non-null  float64
#  14  member_gender            175151 non-null  str
#  15  bike_share_for_all_trip  183416 non-null  str
# dtypes: float64(7), int64(2), str(7)
# memory usage: 37.0 MB

# %%
## I display 15 rows to understand the content values )

df.head(15)
# Out:
#     duration_sec start_time end_time  start_station_id  \
# 0          52185    32:10.1  01:56.0              21.0
# 1          42521    53:21.8  42:03.1              23.0
# 2          61854    13:13.2  24:08.1              86.0
# 3          36490    54:26.0  02:36.8             375.0
# 4           1585    54:18.5  20:44.1               7.0
# 5           1793    49:58.6  19:51.8              93.0
# 6           1147    55:35.1  14:42.6             300.0
# 7           1615    41:06.8  08:02.8              10.0
# 8           1570    41:48.8  07:59.7              10.0
# 9           1049    49:47.7  07:17.0              19.0
# 10           458    57:57.2  05:35.4             370.0
# 11           506    56:55.5  05:21.7              44.0
# 12          1176    45:12.7  04:49.2             127.0
# 13           915    49:06.1  04:21.9             252.0
# 14           395    56:26.8  03:01.9             243.0
#
#                                    start_station_name  start_station_latitude  \
# 0    Montgomery St BART Station (Market St at 2nd St)               37.789625
# 1                       The Embarcadero at Steuart St               37.791464
# 2                             Market St at Dolores St               37.769305
# 3                             Grove St at Masonic Ave               37.774836
# 4                                 Frank H Ogawa Plaza               37.804562
# 5                        4th St at Mission Bay Blvd S               37.770407
# 6                                Palm St at Willow St               37.317298
# 7                          Washington St at Kearny St               37.795393
# 8                          Washington St at Kearny St               37.795393
# 9                                Post St at Kearny St               37.788975
# 10                                Jones St at Post St               37.787327
# 11  Civic Center/UN Plaza BART Station (Market St ...               37.781074
# 12                             Valencia St at 21st St               37.756708
# 13                       Channing Way at Shattuck Ave               37.865847
# 14                        Bancroft Way at College Ave               37.869360
#
#     start_station_longitude  end_station_id  \
# 0               -122.400811            13.0
# 1               -122.391034            81.0
# 2               -122.426826             3.0
# 3               -122.446546            70.0
# 4               -122.271738           222.0
# 5               -122.391198           323.0
# 6               -121.884995           312.0
# 7               -122.404770           127.0
# 8               -122.404770           127.0
# 9               -122.403452           121.0
# 10              -122.413278            43.0
# 11              -122.411738           343.0
# 12              -122.421025           323.0
# 13              -122.267443           244.0
# 14              -122.254337           252.0
#
#                                      end_station_name  end_station_latitude  \
# 0                      Commercial St at Montgomery St             37.794231
# 1                                  Berry St at 4th St             37.775880
# 2        Powell St BART Station (Market St at 4th St)             37.786375
# 3                              Central Ave at Fell St             37.773311
# 4                               10th Ave at E 15th St             37.792714
# 5                                  Broadway at Kearny             37.798014
# 6                            San Jose Diridon Station             37.329732
# 7                              Valencia St at 21st St             37.756708
# 8                              Valencia St at 21st St             37.756708
# 9                                  Mission Playground             37.759210
# 10  San Francisco Public Library (Grove St at Hyde...             37.778768
# 11                                Bryant St at 2nd St             37.783172
# 12                                 Broadway at Kearny             37.798014
# 13                         Shattuck Ave at Hearst Ave             37.873676
# 14                       Channing Way at Shattuck Ave             37.865847
#
#     end_station_longitude  bike_id   user_type  member_birth_year  \
# 0             -122.402923     4902    Customer             1984.0
# 1             -122.393170     2535    Customer                NaN
# 2             -122.404904     5905    Customer             1972.0
# 3             -122.444293     6638  Subscriber             1989.0
# 4             -122.248780     4898  Subscriber             1974.0
# 5             -122.405950     5200  Subscriber             1959.0
# 6             -121.901782     3803  Subscriber             1983.0
# 7             -122.421025     6329  Subscriber             1989.0
# 8             -122.421025     6548  Subscriber             1988.0
# 9             -122.421339     6488  Subscriber             1992.0
# 10            -122.415929     5318  Subscriber             1996.0
# 11            -122.393572     5848  Subscriber             1993.0
# 12            -122.405950     5328    Customer             1990.0
# 13            -122.268487     5101  Subscriber                NaN
# 14            -122.267443     4786  Subscriber             1988.0
#
#    member_gender bike_share_for_all_trip
# 0           Male                      No
# 1            NaN                      No
# 2           Male                      No
# 3          Other                      No
# 4           Male                     Yes
# 5           Male                      No
# 6         Female                      No
# 7           Male                      No
# 8          Other                      No
# 9           Male                      No
# 10        Female                     Yes
# 11          Male                      No
# 12          Male                      No
# 13           NaN                      No
# 14          Male                      No

# %%
# descriptive statistics for numeric variables
df.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  183416.000000     183219.000000           183416.000000
# mean      726.067311        138.590365               37.771221
# std      1794.371831        111.778938                0.099586
# min        61.000000          3.000000               37.317298
# 25%       325.000000         47.000000               37.770083
# 50%       514.000000        104.000000               37.780760
# 75%       796.000000        239.000000               37.797280
# max     85444.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            183416.000000   183219.000000         183416.000000
# mean               -122.352661      136.249401             37.771425
# std                   0.117100      111.514916              0.099494
# min                -122.453705        3.000000             37.317298
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285      100.000000             37.781010
# 75%                -122.286533      235.000000             37.797320
# max                -121.874119      398.000000             37.880222
#
#        end_station_longitude        bike_id  member_birth_year
# count          183416.000000  183416.000000      175151.000000
# mean             -122.352247    4472.890260        1984.806504
# std                 0.116677    1664.386068          10.116589
# min              -122.453705      11.000000        1878.000000
# 25%              -122.411726    3777.000000        1980.000000
# 50%              -122.398279    4958.000000        1987.000000
# 75%              -122.288045    5502.000000        1992.000000
# max              -121.874119    6645.000000        2001.000000

# %% [markdown]
# > ### What is the structure of your dataset?
#
#
#
#
#
# - The structure of the dataset contains  183416 columns and 16 rows.
#
#
# - Most variables are  numerical data type in nature , and here are **dtypes summary :**
#
#         - float (7)
#         - integer number (2)
#         - string(7)
#
#
#
#
# > ### What are the main interesting features in the dataset?
# The main interesting features in the dataset are:
#
# - Trip duration: shows how long each bike trip takes.
# - Start and end stations: show where trips begin and end.
# - User type: identifies whether the user is a Subscriber or Customer.
# - Member gender: provides information about the gender of members.
# - Member birth year: provides information about the age of members.
# - Start and end time: help analyze when people use the bike-sharing service.
#
#
#
#  **We got three main feature areas which are :**
#
#
#
#  The main interesting features are trip duration, start and end time, start and end stations, user type, member birth year, member gender, and bike-sharing information
# -
#
#
#
# -
#
#
#
#
# -
#
#
#
#
# > ### What features in the dataset supported my investigation for these interesting features?
#
#
#
# - The following features support the investigation:
#
# - duration_sec → to analyze trip duration.
#
#
# - start_time and end_time → to analyze trip times and usage patterns.
#
#
# - start_station_name and end_station_name → to identify the most popular stations.
#
#
# - user_type → to compare Customers and Subscribers.
#
# - member_gender → to analyze usage by gender.
#
# - member_birth_year → to analyze users' age.
#
#
#
#
#
# - bike_id → to analyze bike usage.
#
#
#
# -
#
#
#
# -
#
#
#
# -
#
#
#
#
# -

# %% [markdown]
# ##  More Exploring ideas to begin my investigation

# %%
#This code for describing statistical data ideas in a more organized and readable table

df.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  183416.000000     183219.000000           183416.000000
# mean      726.067311        138.590365               37.771221
# std      1794.371831        111.778938                0.099586
# min        61.000000          3.000000               37.317298
# 25%       325.000000         47.000000               37.770083
# 50%       514.000000        104.000000               37.780760
# 75%       796.000000        239.000000               37.797280
# max     85444.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            183416.000000   183219.000000         183416.000000
# mean               -122.352661      136.249401             37.771425
# std                   0.117100      111.514916              0.099494
# min                -122.453705        3.000000             37.317298
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285      100.000000             37.781010
# 75%                -122.286533      235.000000             37.797320
# max                -121.874119      398.000000             37.880222
#
#        end_station_longitude        bike_id  member_birth_year
# count          183416.000000  183416.000000      175151.000000
# mean             -122.352247    4472.890260        1984.806504
# std                 0.116677    1664.386068          10.116589
# min              -122.453705      11.000000        1878.000000
# 25%              -122.411726    3777.000000        1980.000000
# 50%              -122.398279    4958.000000        1987.000000
# 75%              -122.288045    5502.000000        1992.000000
# max              -121.874119    6645.000000        2001.000000

# %%
# display the information about each column

for column in df.columns:
    print(f"Column: {column}")
    print(df[column].info())
    print("---------------------------")
# Out:
# Column: duration_sec
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: duration_sec
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  int64
# dtypes: int64(1)
# memory usage: 1.4 MB
# None
# ---------------------------
# Column: start_time
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: start_time
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  str
# dtypes: str(1)
# memory usage: 2.6 MB
# None
# ---------------------------
# Column: end_time
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: end_time
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  str
# dtypes: str(1)
# memory usage: 2.6 MB
# None
# ---------------------------
# Column: start_station_id
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: start_station_id
# Non-Null Count   Dtype
# --------------   -----
# 183219 non-null  float64
# dtypes: float64(1)
# memory usage: 1.4 MB
# None
# ---------------------------
# Column: start_station_name
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: start_station_name
# Non-Null Count   Dtype
# --------------   -----
# 183219 non-null  str
# dtypes: str(1)
# memory usage: 6.0 MB
# None
# ---------------------------
# Column: start_station_latitude
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: start_station_latitude
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  float64
# dtypes: float64(1)
# memory usage: 1.4 MB
# None
# ---------------------------
# Column: start_station_longitude
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: start_station_longitude
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  float64
# dtypes: float64(1)
# memory usage: 1.4 MB
# None
# ---------------------------
# Column: end_station_id
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: end_station_id
# Non-Null Count   Dtype
# --------------   -----
# 183219 non-null  float64
# dtypes: float64(1)
# memory usage: 1.4 MB
# None
# ---------------------------
# Column: end_station_name
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: end_station_name
# Non-Null Count   Dtype
# --------------   -----
# 183219 non-null  str
# dtypes: str(1)
# memory usage: 6.1 MB
# None
# ---------------------------
# Column: end_station_latitude
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: end_station_latitude
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  float64
# dtypes: float64(1)
# memory usage: 1.4 MB
# None
# ---------------------------
# Column: end_station_longitude
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: end_station_longitude
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  float64
# dtypes: float64(1)
# memory usage: 1.4 MB
# None
# ---------------------------
# Column: bike_id
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: bike_id
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  int64
# dtypes: int64(1)
# memory usage: 1.4 MB
# None
# ---------------------------
# Column: user_type
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: user_type
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  str
# dtypes: str(1)
# memory usage: 3.1 MB
# None
# ---------------------------
# Column: member_birth_year
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: member_birth_year
# Non-Null Count   Dtype
# --------------   -----
# 175151 non-null  float64
# dtypes: float64(1)
# memory usage: 1.4 MB
# None
# ---------------------------
# Column: member_gender
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: member_gender
# Non-Null Count   Dtype
# --------------   -----
# 175151 non-null  str
# dtypes: str(1)
# memory usage: 2.2 MB
# None
# ---------------------------
# Column: bike_share_for_all_trip
# <class 'pandas.Series'>
# RangeIndex: 183416 entries, 0 to 183415
# Series name: bike_share_for_all_trip
# Non-Null Count   Dtype
# --------------   -----
# 183416 non-null  str
# dtypes: str(1)
# memory usage: 1.8 MB
# None
# ---------------------------

# %% [markdown]
# ## <mark>The above result show some missing values exist in some columns So let's display them </mark>

# %%
#yOUR CODES
df.isnull().sum()
# Out:
# duration_sec                  0
# start_time                    0
# end_time                      0
# start_station_id            197
# start_station_name          197
# start_station_latitude        0
# start_station_longitude       0
# end_station_id              197
# end_station_name            197
# end_station_latitude          0
# end_station_longitude         0
# bike_id                       0
# user_type                     0
# member_birth_year          8265
# member_gender              8265
# bike_share_for_all_trip       0
# dtype: int64

# %% [markdown]
# > ## <mark>The result above shows many missing data </mark>
#
#
#
# ###  To fix this issue You will fill these values with ........... for numeric and ......for categorical

# %%
# trying to fill missing values in my datset using for loop 

for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:
        df[column] = df[column].fillna(df[column].mean())
    else:
        df[column] = df[column].fillna(df[column].mode()[0])

# %%
df.isnull().sum()
# Out:
# duration_sec               0
# start_time                 0
# end_time                   0
# start_station_id           0
# start_station_name         0
# start_station_latitude     0
# start_station_longitude    0
# end_station_id             0
# end_station_name           0
# end_station_latitude       0
# end_station_longitude      0
# bike_id                    0
# user_type                  0
# member_birth_year          0
# member_gender              0
# bike_share_for_all_trip    0
# dtype: int64

# %% [markdown]
# ### **And with a proper category for other (member gender)**

# %%
##  still got a missing value in the member_gender, so let's explore this column more 

print(df['member_gender'].head(15))
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3      Other
# 4       Male
# 5       Male
# 6     Female
# 7       Male
# 8      Other
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# Name: member_gender, dtype: str

# %%
# Fill missing values

df['member_gender'] = df['member_gender'].fillna(df['member_gender'].mode()[0])

df['age'] = df['age'].fillna(df['age'].median())

# %%
# print(gbf.member_gender.head(15))
print(df['member_gender'].head(15))
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# 5       Male
# 6     Female
# 7       Male
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# Name: member_gender, dtype: str

# %%
## check my result above 
df.isnull().sum()
# Out:
# duration_sec               0
# start_time                 0
# end_time                   0
# start_station_id           0
# start_station_name         0
# start_station_latitude     0
# start_station_longitude    0
# end_station_id             0
# end_station_name           0
# end_station_latitude       0
# end_station_longitude      0
# bike_id                    0
# user_type                  0
# member_birth_year          0
# member_gender              0
# bike_share_for_all_trip    0
# age                        0
# duration_minute            0
# duration_houre             0
# duration_min               0
# dtype: int64

# %% [markdown]
# > ## <mark>The result above shows that we deal with all missing data </mark>

# %% [markdown]
# ### Now let's check duplicate value

# %%
##  check duplicate in dataset
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# > ##If Not significant duplicated , so won't clean it
#
#
# ### Now let's check the category columns to make more cleaning dataset

# %%
### check the category columns that included object
 
categorical_columns = df.select_dtypes(include='object').columns

print(categorical_columns)
# Out:
# Index(['start_time', 'end_time', 'start_station_name', 'end_station_name',
#        'user_type', 'member_gender', 'bike_share_for_all_trip'],
#       dtype='str')
# C:\Users\MOSTAFA\AppData\Local\Temp\ipykernel_5516\1715690338.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(include='object').columns

# %% [markdown]
#  > ## From all previous results above I found  :
#
#
#
#  **=========================================================**
#
#
#
# > 1 ) **unique Value** as in ((`member_gender`)) : Not significant , so won't clean it
#
#
#
# > 2 ) **Incorrect data type** as in (( `user_type` &&	`member_gender`)) :  significant change , so I need to clean it.
#
#
# > 3 ) **Good factor** for marketing work as in ((`member_birth_year`)) : so I need to clean it.

# %%
df['user_type'].unique()
# Out:
# <ArrowStringArray>
# ['Customer', 'Subscriber']
# Length: 2, dtype: str

# %%
##  step  2 ) Incorrect data type as in (( `user_type` &&	`member_gender`)) :  significant change , so  need to clean it.

df['member_gender'].unique()

s=df['member_gender'].mode()[0]
df['member_gender'] = df['member_gender'].replace('Other', s)

# %%
## check your work 
df['member_gender'].unique()
# Out:
# <ArrowStringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
## step 3 ) Good factor for marketing work as in ((`member_birth_year`)) : so need to clean it.
## To know the target audience's age and serve on them

# create a column for users' age depending on the current year
# Create a column for users' age
df['age'] = 2019 - df['member_birth_year']

# %%
## check your work 
df[['member_birth_year', 'age']].head()
# Out:
#    member_birth_year        age
# 0        1984.000000  35.000000
# 1        1984.806504  34.193496
# 2        1972.000000  47.000000
# 3        1989.000000  30.000000
# 4        1974.000000  45.000000

# %%
df['age'].describe()
# Out:
# count    183412.000000
# mean         34.193560
# std           9.886118
# min          18.000000
# 25%          27.000000
# 50%          32.000000
# 75%          38.000000
# max         141.000000
# Name: age, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  str
#  2   end_time                 183412 non-null  str
#  3   start_station_id         183412 non-null  float64
#  4   start_station_name       183412 non-null  str
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183412 non-null  float64
#  8   end_station_name         183412 non-null  str
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  str
#  13  member_birth_year        183412 non-null  float64
#  14  member_gender            183412 non-null  str
#  15  bike_share_for_all_trip  183412 non-null  str
#  16  age                      183412 non-null  float64
# dtypes: float64(8), int64(2), str(7)
# memory usage: 38.5 MB

# %%
## change the new column age data type from float to int
df['age'] = df['age'].astype(int)
df['age']
# Out:
# 0         35
# 1         34
# 2         47
# 3         30
# 4         45
#           ..
# 183407    23
# 183408    35
# 183409    29
# 183410    31
# 183411    30
# Name: age, Length: 183412, dtype: int64

# %%
## create a function to know the average users ages
df['age'].mean()
# Out:
# np.float64(34.184840686541776)

# %%
## another important factor to offer  marketing services is the trip duration time 

## need to change the time from second to minute to be more usable
print( df['duration_sec'] )
df['duration_minute'] = df['duration_sec'] / 60
print(df['duration_minute'])
# Out:
# 0         52185
# 1         42521
# 2         61854
# 3         36490
# 4          1585
#           ...
# 183407      480
# 183408      313
# 183409      141
# 183410      139
# 183411      271
# Name: duration_sec, Length: 183412, dtype: int64
# 0          869.750000
# 1          708.683333
# 2         1030.900000
# 3          608.166667
# 4           26.416667
#              ...
# 183407       8.000000
# 183408       5.216667
# 183409       2.350000
# 183410       2.316667
# 183411       4.516667
# Name: duration_minute, Length: 183412, dtype: float64

# %%
## I need to change the time from second to Houre  to be more usable
df['duration_houre'] = df['duration_sec'] / 3600

# %%
## check your work 
print(df[['duration_sec', 'duration_minute', 'duration_houre']].head())
# Out:
#    duration_sec  duration_minute  duration_houre
# 0         52185       869.750000       14.495833
# 1         42521       708.683333       11.811389
# 2         61854      1030.900000       17.181667
# 3         36490       608.166667       10.136111
# 4          1585        26.416667        0.440278

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Univariate Exploration</p>
# # <a id="011"> Univariate Exploration</a>
#
#
#
# > In this section, investigate distributions of individual variables. If
# you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.

# %% [markdown]
# # <a id="1"> 1 ) . What is the distribution for User type?</a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5), dpi=200)

sns.countplot(data=df, x='user_type')

plt.xlabel('User Type')
plt.ylabel('Frequency')
plt.title('Distribution of User Type')

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
#
# The graph shows that Subscribers are much more common than Customers. This means that most users are regular members of the GoBike service. The company could focus on encouraging Customers to become Subscribers.

# %% [markdown]
# # <a id="2"> 2 ) What is the distribution for the bike share users on all Trips?</a>

# %%
plt.figure(figsize=(10, 5), dpi=200)
sns.countplot(data=df, x='bike_share_for_all_trip')
plt.xlabel('Bike Share for All Trip')
plt.ylabel('Frequency')
plt.title('Distribution of Bike Share for All Trip')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# Most users did not use bike share for all trips, while only a small number of users used it. This means that the bike share option is not very popular among users, so the company could promote it more.

# %% [markdown]
# # <a id="3"> 3 ) What is the distribution for users' ages? </a>

# %%
plt.figure(figsize=(12, 6), dpi=200)

sns.histplot(data=df, x='age', bins=30)

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title("Distribution of Users' Ages")

plt.xticks(range(10, 101, 5))

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# The age distribution is right-skewed, with most users between 20 and 40 years old. The highest concentration of users is around 30–35 years old. The number of users gradually decreases as age increases, with very few users above 60 years old. Therefore, the company can focus its marketing campaigns mainly on users between 20 and 40 years old.

# %% [markdown]
# # <a id="4">  4 ) . Do the users' ages have outlier values?</a>

# %%
plt.figure(figsize=(10, 5), dpi=200)

sns.boxplot(data=df, x='age')

plt.xlabel('Age')
plt.title("Distribution of Users' Ages")

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
#
# The boxplot shows that most users are relatively young, with a median age of around 30 years. There are several outliers representing users with higher ages, especially above 50 years. These values should be checked to determine whether they are valid or incorrect before further analysis

# %% [markdown]
# # <a id="5">  5 ) . What is the distribution for the trip duration in minutes? </a>

# %%
## Review the statistic for trip duration in minutes

df['duration_minute'].describe()
# Out:
# count    183412.000000
# mean         12.101307
# std          29.906496
# min           1.016667
# 25%           5.416667
# 50%           8.566667
# 75%          13.266667
# max        1424.066667
# Name: duration_minute, dtype: float64

# %%
# Make visualization to easy get insight

plt.figure(figsize=(10, 5), dpi=200)

sns.histplot(data=df, x='duration_minute', bins=50)

plt.xlabel('Trip Duration (Minutes)')
plt.ylabel('Frequency')
plt.title('Distribution of Trip Duration in Minutes')

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# Most trips have a short duration, while only a few trips have very long durations. The distribution is highly right-skewed, with some possible outliers that should be checked before further analysis.

# %% [markdown]
# # <a id="6"> 6 ) . What is the distribution for member_gender?</a>

# %%
# Make visualization to easy get insight
df['member_gender'] . describe()
# Out:
# count     183412
# unique         2
# top         Male
# freq      142568
# Name: member_gender, dtype: object

# %%
plt.figure(figsize=(10, 5), dpi=200)
sns.countplot(data=df, x='member_gender')
plt.xlabel('Member Gender')
plt.ylabel('Frequency')
plt.title('Distribution of Member Gender')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
#
# > **The graph shows that male users are significantly more common than female users. There are approximately three times as many male users as female users. This indicates that the service is more popular among male users, so marketing campaigns could focus on attracting more female users while maintaining the existing male customer base.**

# %% [markdown]
# # <a id="7">    7 )  . What is the distribution for the trip duration in Hours?  </a>

# %%
# Make visualization to easy get insight
df['duration_houre'].describe()
# Out:
# count    183412.000000
# mean          0.201688
# std           0.498442
# min           0.016944
# 25%           0.090278
# 50%           0.142778
# 75%           0.221111
# max          23.734444
# Name: duration_houre, dtype: float64

# %%
plt.figure(figsize=(10, 5), dpi=200)
sns.histplot(data=df, x='duration_houre', bins=50)
plt.xlabel('Trip Duration (Hours)')
plt.ylabel('Frequency') 
plt.title('Distribution of Trip Duration in Hours')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# > **Most trips are short, usually less than one hour, while only a few trips last much longer. This creates a right-skewed distribution.**

# %% [markdown]
# ### The variables distribution:
#
#
# > The distribution of duration present that most of the trips were less than 30 minutes ( we can notice that from the minutes and the hour charts )
#
#
# > And the Age distribution is ( left Skewed ) as most users age are  22 - 39
#
#
# > Most users are subscribers, not Customers and  Males as shown in the charts above.
#
#
#
# ### Were there any interesting and outliers
#
#
# - We got Age outliers for for more than 100 .
#
#
#
# - The distribution of duration was strange where the minutes and the hour charts were 30 minutes or less.

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Bivariate Exploration</p>
# # <a id="111"> Bivariate Exploration</a>
#
# Now let's investigate relationships between pairs of variables in our data.

# %% [markdown]
# # <a id="8"> 8) . What the average duration of trip for the categories of user type?</a>

# %%
# Distribution of Age by user types
avg_duration = df.groupby('user_type')['duration_houre'].mean()

avg_duration
# Out:
# user_type
# Customer      0.397907
# Subscriber    0.177851
# Name: duration_houre, dtype: float64

# %%
plt.figure(figsize=(8, 5), dpi=200)

sns.barplot(x=avg_duration.index, y=avg_duration.values)

plt.xlabel('User Type')
plt.ylabel('Average Trip Duration (Hours)')
plt.title('Average Trip Duration by User Type')

plt.show()

# %% [markdown]
# # Make visualization to easy get insight

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# The bar chart compares the average trip duration across different user types. It shows that Customers tend to have a longer average trip duration than Subscribers. This suggests that Customers may use the bike-sharing service for longer or more occasional trips, while Subscribers appear to use the service more regularly for shorter trips, possibly for commuting or daily transportation. Overall, user type seems to have an impact on trip duration, with a clear difference in the average duration between the two groups.

# %% [markdown]
# # <a id="9">    9 ) . How long is the duration of the trip for each gender in minutes?  </a>

# %%
# Make visualization to easy get insight

# ------------------------Duration distribution by member gender

avg_duration_gender = df.groupby('member_gender')['duration_minute'].mean()

avg_duration_gender
# Out:
# member_gender
# Female    12.984506
# Male      11.848281
# Name: duration_minute, dtype: float64

# %%
plt.figure(figsize=(8, 5), dpi=200)

sns.barplot(x=avg_duration_gender.index, y=avg_duration_gender.values)

plt.xlabel('Gender')
plt.ylabel('Average Trip Duration (Minutes)')
plt.title('Average Trip Duration by Gender')

plt.show()

# %% [markdown]
# # Make visualization to easy get insight

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
# > **The chart compares the average trip duration for each gender. It shows that there is a difference in the average duration between genders. Overall, the average trip duration is relatively similar across the groups, with some genders having slightly longer trips than others. This suggests that gender may have a small influence on trip duration, but the difference is not very large.**

# %% [markdown]
# # <a id="10 "> 10 ) . How long is the duration of the trip for each user_type in minutes?  </a>

# %%
# The notebook uses duration_minute, not duration_min
df['duration_min'] = df['duration_minute']

# Make visualization to easy get insight
avg_duration_user = df.groupby('user_type')['duration_min'].mean()

avg_duration_user
# Out:
# user_type
# Customer      23.874417
# Subscriber    10.671061
# Name: duration_min, dtype: float64

# %%
plt.figure(figsize=(8, 5), dpi=200)

sns.barplot(x=avg_duration_user.index, y=avg_duration_user.values)

plt.xlabel('User Type')
plt.ylabel('Average Trip Duration (Minutes)')
plt.title('Average Trip Duration by User Type')

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# The chart shows the average trip duration for each user type. Customers have a higher average trip duration than Subscribers. This indicates that Customers tend to spend more time on each trip, while Subscribers usually take shorter trips.

# %% [markdown]
# # <a id="11">  11 ) . How the user distribution depending on their Age and user_type ? </a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(10, 5), dpi=200)

sns.boxplot(data=df, x='user_type', y='age')

plt.xlabel('User Type')
plt.ylabel('Age')
plt.title('Age Distribution by User Type')

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# The chart shows that most Customers and Subscribers are between about 25 and 40 years old. Subscribers have a slightly wider age range, while both groups contain several older users that appear as outliers. Overall, the age distributions of the two user types are quite similar.

# %% [markdown]
# #  <a id="12"> 12 ). How the user distribution depending on their Age and member_gender ?</a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(10, 5), dpi=200)

sns.boxplot(data=df, x='member_gender', y='age')

plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Age Distribution by Gender')

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# The chart shows the age distribution across different genders. Most users are between 25 and 40 years old, while some older users appear as outliers. Overall, the age distribution is fairly similar across genders.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# >
# Trip duration varies with user type, gender, and age. Customers generally have longer trips than Subscribers. Most users are between 25 and 40 years old, and the age distribution is similar across user types and genders.
#
#
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > User type and gender show noticeable differences in trip duration. Subscribers tend to take shorter trips, while Customers tend to have longer trips. Age also varies slightly between the user groups, with some older users appearing as outliers.

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Multivariate Exploration</p>
# # <a id="1111"> Multivariate Exploration </a>
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %%
## check your work 
plt.figure(figsize=(10, 6), dpi=200)

sns.scatterplot(
    data=df,
    x='age',
    y='duration_min',
    hue='user_type',
    style='member_gender',
    alpha=0.5
)

plt.xlabel('Age')
plt.ylabel('Trip Duration (Minutes)')
plt.title('Trip Duration by Age, User Type, and Gender')

plt.show()

# %% [markdown]
# # <a id="13">  13 ) . What is the  Correlation between each variable in the dataset?</a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(10, 7), dpi=200)

corr = df.select_dtypes(include='number').corr()

sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')

plt.title('Correlation Between Numerical Variables')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
# Example usage
# - There is `no Correlation` for any variable with time ( `duration sec /minutes/hours`)
# The correlation matrix shows the relationships between the numerical variables in the dataset. Most variables have weak to moderate correlations, while some variables show stronger relationships. Trip duration has a noticeable relationship with some numerical features, while age generally has a weak correlation with trip duration.

# %% [markdown]
# # <a id="14"> 14 )  .  What is the  Correlation between `specific numeric variables` in the dataset?</a>

# %%
# Make visualization to easy get insight

plt.figure(figsize=(8, 5), dpi=200)

sns.scatterplot(data=df, x='age', y='duration_min', alpha=0.3)

plt.xlabel('Age')
plt.ylabel('Trip Duration (Minutes)')
plt.title('Correlation Between Age and Trip Duration')

plt.show()

print("Correlation:", df['age'].corr(df['duration_min']))
# Out:
# Correlation: 0.005160054095810446

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
# Example usage
# - There is `no Correlation` for any variable with time ( `duration sec /minutes`)
#
#
#
#
# - There is a weak correlation between age and trip duration
#
#
#
#
# - This means that age does not have a strong relationship with the duration of the trip

# %% [markdown]
# # <a id="15">  15 ) What is the  Correlation between data_stat variables in the dataset?</a>

# %%
"""This time, I will use a heatmap to explain the correlation
between the numerical variables in the dataset
in a clear and specific way."""

# Make visualization easy to get insights

plt.figure(figsize=(10, 7), dpi=200)

corr = df.select_dtypes(include='number').corr()

sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')

plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# > ### <mark>The above charts show how Correlation between specific numeric variables in the dataset using heatmap plots  </mark>
#
#
#
# **Actually the `heat map`  display the above ideas in clear percentages**
#
#
#
# - There is `no Correlation` for any variable with time ( `duration sec /minutes`)
#
#
#
#
# - There is a `negative  Correlation` between  member_birth_year  and age which normal.
#
#
#
#
# - There is `no significant Correlation` for any variable with `bike_id `

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Conclusions</p>
# # <a id="1100"> Conclusions </a>
#
# #example
# - Most users were Male.
#
#
# -  Most users were Subscribers rather than Customers.
# - Most trips were short, usually less than one hour.
# - Customers generally had longer trips than Subscribers.
# - Most users were between 25 and 40 years old.
# - Age had a weak relationship with trip duration.
# - Some very old users appeared as outliers in the age distribution.
#
# -
#
# -
#
#
#
# ## limitation
# example
# - We got missing data which we fix some of them .
#
# - The dataset contains some missing values, and some of them were removed or handled during data cleaning.
# - There are some outliers, especially in age and trip duration, which may affect the analysis.
# - Some variables, such as gender and user type, are categorical, so their correlation with numerical variables cannot be directly measured using Pearson correlation.
# - The analysis describes relationships in the data but does not prove that one variable causes another.
